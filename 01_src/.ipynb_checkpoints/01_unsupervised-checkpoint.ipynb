# %% [markdown]
# # Unsupervised
# Here is where we will do the unsupervised clustering analysis of the data to find the specific different play styles

# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.decomposition import PCA
print('imports done!')
# Out:
# imports done!

# %%
# helper functions

# %%
# pull in the data frame
df = pd.read_csv('./df_final.csv')

# show
df
# Out:
#      Unnamed: 0   Age     G    GS  MP_x    FG   FGA    FG%   3P  3PA  ...  \
# 0             0  26.0  76.0  76.0  34.2  11.3  21.8  0.519  2.1  5.7  ...
# 1             1  30.0  67.0  67.0  34.2  11.8  19.7  0.601  0.2  0.9  ...
# 2             2  29.0  70.0  70.0  36.7  11.2  19.5  0.576  2.0  4.7  ...
# 3             3  25.0  22.0  22.0  35.7   9.8  21.2  0.464  3.4  9.6  ...
# 4             4  25.0  28.0  28.0  35.1   8.8  20.0  0.438  3.6  9.6  ...
# ..          ...   ...   ...   ...   ...   ...   ...    ...  ...  ...  ...
# 546         620  23.0  20.0   0.0   6.3   0.6   1.7  0.324  0.1  0.9  ...
# 547         627  26.0  33.0   2.0   7.0   0.4   1.6  0.245  0.2  1.0  ...
# 548         628  23.0  12.0   0.0   7.3   0.4   1.7  0.250  0.0  0.8  ...
# 549         630  25.0  19.0   0.0   5.3   0.4   1.1  0.381  0.1  0.5  ...
# 550         632  24.0   4.0   0.0   8.3   0.3   1.8  0.143  0.0  0.8  ...
#
#       OWS  DWS    WS  WS/48  OBPM  DBPM   BPM  VORP                   Player  \
# ...

# %%
### make per minutes rates
dict_perminute = {'2PA_per_min': df['2PA'] / df['MP_x'],
                 '3PA_per_min': df['3PA'] / df['MP_x'],
                 'FTA_per_min': df['FTA'] / df['MP_x'],
                 'PTS_per_min': df['PTS'] / df['MP_x'],
                 'AST_per_min': df['AST'] / df['MP_x'],
                 'ORB_per_min': df['ORB'] / df['MP_x'],
                 'DRB_per_min': df['DRB'] / df['MP_x'],
                 'STL_per_min': df['STL'] / df['MP_x'],
                 'BLK_per_min': df['BLK'] / df['MP_x'],
                 '3PAr': df['3PAr'],
                 'USG%': df['USG%'],
                 'FTr': df['FTr'],
                 }

df_perminute = pd.DataFrame(dict_perminute)

df_perminute
# Out:
#      2PA_per_min  3PA_per_min  FTA_per_min  PTS_per_min  AST_per_min  \
# 0       0.470760     0.166667     0.257310     0.956140     0.187135
# 1       0.546784     0.026316     0.309942     0.888889     0.190058
# 2       0.403270     0.128065     0.174387     0.806540     0.277929
# 3       0.322129     0.268908     0.184874     0.787115     0.218487
# 4       0.296296     0.273504     0.253561     0.803419     0.213675
# ..           ...          ...          ...          ...          ...
# 546     0.142857     0.142857     0.031746     0.206349     0.047619
# 547     0.085714     0.142857     0.014286     0.142857     0.028571
# 548     0.123288     0.109589     0.027397     0.136986     0.095890
# 549     0.113208     0.094340     0.018868     0.169811     0.075472
# 550     0.120482     0.096386     0.036145     0.096386     0.096386
#
#      ORB_per_min  DRB_per_min  STL_per_min  BLK_per_min   3PAr  USG%    FTr
# ...

# %%
#### Standardize the data
#get the colnames
colnames = df_perminute.columns

# init the scalar
scalar = StandardScaler()
# fit the scalar and transform
df_scaled = pd.DataFrame(
    scalar.fit_transform(df_perminute),
    columns=colnames,
    index=df_perminute.index
)

# show
df_scaled
# Out:
#      2PA_per_min  3PA_per_min  FTA_per_min  PTS_per_min  AST_per_min  \
# 0       3.112213     0.195823     3.644994     3.719816     1.548331
# 1       3.978070    -1.695639     4.742586     3.242835     1.602019
# 2       2.343539    -0.324394     1.915697     2.658773     3.215444
# 3       1.419396     1.573689     2.134396     2.521004     2.124013
# 4       1.125180     1.635637     3.566818     2.636640     2.035654
# ..           ...          ...          ...          ...          ...
# 546    -0.622393    -0.125050    -1.058972    -1.598071    -1.013363
# 547    -1.273214    -0.125050    -1.423094    -2.048388    -1.363103
# 548    -0.845277    -0.573394    -1.149663    -2.090027    -0.127035
# 549    -0.960083    -0.778905    -1.327535    -1.857216    -0.501951
# 550    -0.877233    -0.751333    -0.967244    -2.377988    -0.117944
#
#      ORB_per_min  DRB_per_min  STL_per_min  BLK_per_min      3PAr      USG%  \
# ...

# %% [markdown]
# ### Finding ideal K

# %%
inertia = []
k_values = range(2, 21)

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(df_scaled)
    inertia.append(kmeans.inertia_)

plt.plot(k_values, inertia, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Inertia")
plt.title("Elbow Method")
plt.savefig('../03_progress/plots/KMeans_elbow.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
sil_scores = []

for k in k_values:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    labels = kmeans.fit_predict(df_scaled)
    sil_scores.append(silhouette_score(df_scaled, labels))

plt.plot(k_values, sil_scores, marker='o')
plt.xlabel("Number of Clusters (k)")
plt.ylabel("Silhouette Score")
plt.title("Silhouette Scores")
plt.savefig('../03_progress/plots/KMeans_Silhouette.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
sil_scores
# Out:
# [0.23273275963756518,
#  0.2650751262846938,
#  0.17867409626613168,
#  0.16238405124250915,
#  0.1584166229477558,
#  0.151904761592454,
#  0.14951691208762904,
#  0.1564535368372207,
#  0.1373132102405295,
#  0.12757361653531957,
#  0.1392109821231362,
#  0.13401314609354276,
#  0.1346847723598,
#  0.13200113413502057,
#  0.13656922324070384,
#  0.12876839811206828,
#  0.1283905428528405,
#  0.12786373245453056,
#  0.12833553982039658]

# %%
# I like doing 9 clusters

# %% [markdown]
# ### Clustering

# %%
feature_cols = [
    '2PA_per_min', '3PA_per_min', 'FTA_per_min', 'PTS_per_min',
    'AST_per_min', 'ORB_per_min', 'DRB_per_min', 'STL_per_min',
    'BLK_per_min', '3PAr', 'USG%', 'FTr'
]

X = df_scaled[feature_cols].copy()

kmeans_9 = KMeans(n_clusters=9, random_state=42, n_init=10)
df_scaled['cluster_9'] = kmeans_9.fit_predict(X)

kmeans_3 = KMeans(n_clusters=3, random_state=42, n_init=10)
df_scaled['cluster_3'] = kmeans_3.fit_predict(X)

df_perminute['cluster_3'] = df_scaled['cluster_3']
df_perminute['cluster_9'] = df_scaled['cluster_9']

df['cluster_3'] = df_scaled['cluster_3']
df['cluster_9'] = df_scaled['cluster_9']

cluster_summary_3 = df_perminute.groupby('cluster_3').mean(numeric_only=True)
cluster_summary_9 = df_perminute.groupby('cluster_9').mean(numeric_only=True)

# %%
cluster_summary_3
# Out:
#            2PA_per_min  3PA_per_min  FTA_per_min  PTS_per_min  AST_per_min  \
# cluster_3
# 0             0.292193     0.182564     0.140975     0.614543     0.148305
# 1             0.146031     0.170345     0.055441     0.370667     0.093503
# 2             0.231349     0.062626     0.089872     0.386073     0.074506
#
#            ORB_per_min  DRB_per_min  STL_per_min  BLK_per_min      3PAr  \
# cluster_3
# 0             0.036049     0.134506     0.036056     0.016368  0.384244
# 1             0.038047     0.112023     0.036374     0.015745  0.539744
# 2             0.096480     0.195688     0.031895     0.039572  0.200287
#
#                 USG%       FTr  cluster_9
# cluster_3
# 0          26.145802  0.299733   3.221374
# 1          16.508013  0.178205   4.179487
# 2          16.275926  0.317463   5.000000

# %%
print(cluster_summary_3.to_markdown())
# Out:
# |   cluster_3 |   2PA_per_min |   3PA_per_min |   FTA_per_min |   PTS_per_min |   AST_per_min |   ORB_per_min |   DRB_per_min |   STL_per_min |   BLK_per_min |     3PAr |    USG% |      FTr |   cluster_9 |
# |------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|---------:|--------:|---------:|------------:|
# |           0 |      0.292193 |     0.182564  |     0.140975  |      0.614543 |     0.148305  |     0.0360494 |      0.134506 |     0.0360557 |     0.0163681 | 0.384244 | 26.1458 | 0.299733 |     3.22137 |
# |           1 |      0.146031 |     0.170345  |     0.0554415 |      0.370667 |     0.0935034 |     0.038047  |      0.112023 |     0.0363738 |     0.0157453 | 0.539744 | 16.508  | 0.178205 |     4.17949 |
# ...

# %%
cluster_map = {
    0: 'High Volume Offensive Stars',
    1: 'Balanced Role Players',
    2: 'Rebounding Bigs',
}
df['cluster_3_label'] = df['cluster_3'].map(cluster_map)

# %%
cluster_summary_9
# Out:
#            2PA_per_min  3PA_per_min  FTA_per_min  PTS_per_min  AST_per_min  \
# cluster_9
# 0             0.377979     0.098907     0.182707     0.658725     0.127938
# 1             0.120581     0.232788     0.046503     0.422392     0.083445
# 2             0.200932     0.198667     0.085465     0.486833     0.068524
# 3             0.282341     0.207708     0.136311     0.631281     0.148660
# 4             0.107153     0.143809     0.037588     0.278406     0.068297
# 5             0.193316     0.125025     0.086305     0.396313     0.080414
# 6             0.236354     0.028276     0.083444     0.364301     0.070457
# 7             0.175122     0.130883     0.081189     0.349849     0.099443
# 8             0.201174     0.146379     0.067374     0.400503     0.173223
#
#            ORB_per_min  DRB_per_min  STL_per_min  BLK_per_min      3PAr  \
# cluster_9
# 0             0.080408     0.207429     0.033824     0.029933  0.206407
# ...

# %%
print(cluster_summary_9.to_markdown())
# Out:
# |   cluster_9 |   2PA_per_min |   3PA_per_min |   FTA_per_min |   PTS_per_min |   AST_per_min |   ORB_per_min |   DRB_per_min |   STL_per_min |   BLK_per_min |     3PAr |    USG% |      FTr |   cluster_3 |
# |------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|--------------:|---------:|--------:|---------:|------------:|
# |           0 |      0.377979 |     0.0989073 |     0.182707  |      0.658725 |     0.127938  |     0.0804081 |     0.207429  |     0.0338243 |     0.0299327 | 0.206407 | 26.9185 | 0.383444 |    0.518519 |
# |           1 |      0.120581 |     0.232788  |     0.0465033 |      0.422392 |     0.0834449 |     0.0260884 |     0.10146   |     0.0286183 |     0.0109377 | 0.662512 | 17.6631 | 0.13206  |    1        |
# ...

# %%
cluster_map = {
    0: 'Interior Scoring Stars',
    1: 'High Volume Three Point Specialists',
    2: 'Stretch Bigs',
    3: 'Primary Offensive Engines',
    4: 'Low Usage Floor Spacers',
    5: 'Balanced Role Players',
    6: 'Traditional Interior Bigs',
    7: 'Defensive Guards',
    8: 'Secondary Playmakers'
}
df['cluster_9_label'] = df['cluster_9'].map(cluster_map)

# %% [markdown]
# ### PCA Plots

# %%
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled.drop(['cluster_3', 'cluster_9'], axis=1))

sns.scatterplot(
    x=df_pca[:, 0],
    y=df_pca[:, 1],
    hue=df['cluster_9_label']
)

plt.title("PCA of Player Archetypes (k=9)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(
    title="Player Archetypes (k=9)",
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)
plt.savefig('../03_progress/plots/PCA_k=9.png', bbox_inches='tight', dpi=300)
plt.show()

# %%
pca = PCA(n_components=2)
df_pca = pca.fit_transform(df_scaled.drop(['cluster_3', 'cluster_9'], axis=1))

sns.scatterplot(
    x=df_pca[:, 0],
    y=df_pca[:, 1],
    hue=df['cluster_3_label']
)

plt.title("PCA of Player Archetypes (k=3)")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.legend(
    title="Player Archetypes(k=3) ",
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)
plt.savefig('../03_progress/plots/PCA_k=3.png', bbox_inches='tight', dpi=300)
plt.show()

# %% [markdown]
# ### Save the df with the labels

# %%
# take a looks
df
# Out:
#      Unnamed: 0   Age     G    GS  MP_x    FG   FGA    FG%   3P  3PA  ...  \
# 0             0  26.0  76.0  76.0  34.2  11.3  21.8  0.519  2.1  5.7  ...
# 1             1  30.0  67.0  67.0  34.2  11.8  19.7  0.601  0.2  0.9  ...
# 2             2  29.0  70.0  70.0  36.7  11.2  19.5  0.576  2.0  4.7  ...
# 3             3  25.0  22.0  22.0  35.7   9.8  21.2  0.464  3.4  9.6  ...
# 4             4  25.0  28.0  28.0  35.1   8.8  20.0  0.438  3.6  9.6  ...
# ..          ...   ...   ...   ...   ...   ...   ...    ...  ...  ...  ...
# 546         620  23.0  20.0   0.0   6.3   0.6   1.7  0.324  0.1  0.9  ...
# 547         627  26.0  33.0   2.0   7.0   0.4   1.6  0.245  0.2  1.0  ...
# 548         628  23.0  12.0   0.0   7.3   0.4   1.7  0.250  0.0  0.8  ...
# 549         630  25.0  19.0   0.0   5.3   0.4   1.1  0.381  0.1  0.5  ...
# 550         632  24.0   4.0   0.0   8.3   0.3   1.8  0.143  0.0  0.8  ...
#
#      OBPM  DBPM   BPM  VORP                   Player  Team  cluster_3  \
# ...

# %%
# save the data frame
df.to_csv('./df_labels.csv')

# %% [markdown]
# # Demonstration
# This notebook is designed to give a simple demonstration of the machine learning models trained. It will go through all of the steps of collecting the data, splitting the data, prepping the data, fitting models, and then showing their outputs in one place
